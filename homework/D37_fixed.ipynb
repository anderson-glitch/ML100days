# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display

# %%
#-----------------------------------------
missing_vals = df_train.isnull().sum()/len(df_train)
missing_vals.sort_values(ascending=False)
missing_vals = pd.DataFrame(missing_vals,columns=['missing_rate'])
print(missing_vals)
missing_index=data.isnull()
display(data[missing_index.values==True])
print(df_train['Age'].mean()) 
print(df_train['Age'].std()) 
g = sns.FacetGrid(df_train, col='Survived')
g.map(sns.distplot, 'Age', kde=False)
#-----------------------------------
train = pd.read_csv('Titanic_train.csv')
train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-df0744b7bae0> in <module>
#       1 #-----------------------------------------
# ----> 2 missing_vals = df_train.isnull().sum()/len(df_train)
#       3 missing_vals.sort_values(ascending=False)
#       4 missing_vals = pd.DataFrame(missing_vals,columns=['missing_rate'])
#       5 print(missing_vals)
#
# NameError: name 'df_train' is not defined

# %%
data = train[['Age', 'Pclass', 'Sex','PassengerId','Survived','Name','SibSp','Parch','Ticket','Fare','Cabin','Embarked']]

# %%
 inf = data.iloc[0:891, 0:3]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
inf['Sex']=le.fit_transform(inf['Sex'])
display(inf)
# Out:
#       Age  Pclass  Sex
# 0    22.0       3    1
# 1    38.0       1    0
# 2    26.0       3    0
# 3    35.0       1    0
# 4    35.0       3    1
# ..    ...     ...  ...
# 886  27.0       2    1
# 887  19.0       1    0
# 888   NaN       3    0
# 889  26.0       1    1
# 890  32.0       3    1
#
# [891 rows x 3 columns]

# %%
from sklearn.metrics.pairwise import nan_euclidean_distances
display(pd.DataFrame(nan_euclidean_distances(inf)))
# Out:
#            0          1          2          3          4         5    \
# 0     0.000000  16.155494   4.123106  13.190906  13.000000  0.000000
# 1    16.155494   0.000000  12.165525   3.000000   3.741657  2.738613
# 2     4.123106  12.165525   0.000000   9.219544   9.055385  1.224745
# 3    13.190906   3.000000   9.219544   0.000000   2.236068  2.738613
# 4    13.000000   3.741657   9.055385   2.236068   0.000000  0.000000
# ..         ...        ...        ...        ...        ...       ...
# 886   5.099020  11.090537   1.732051   8.124038   8.062258  1.224745
# 887   3.741657  19.000000   7.280110  16.000000  16.155494  2.738613
# 888   1.224745   2.449490   0.000000   2.449490   1.224745  1.224745
# 889   4.472136  12.041595   2.236068   9.055385   9.219544  2.449490
# 890  10.000000   6.403124   6.082763   3.741657   3.000000  0.000000
#
#            6          7          8          9    ...        881        882  \
# ...

# %%
value_neighbors=1
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=value_neighbors)
df_filled = pd.DataFrame(imputer.fit_transform(inf))
display(df_filled)
# Out:
#         0    1    2
# 0    22.0  3.0  1.0
# 1    38.0  1.0  0.0
# 2    26.0  3.0  0.0
# 3    35.0  1.0  0.0
# 4    35.0  3.0  1.0
# ..    ...  ...  ...
# 886  27.0  2.0  1.0
# 887  19.0  1.0  0.0
# 888  26.0  3.0  0.0
# 889  26.0  1.0  1.0
# 890  32.0  3.0  1.0
#
# [891 rows x 3 columns]
